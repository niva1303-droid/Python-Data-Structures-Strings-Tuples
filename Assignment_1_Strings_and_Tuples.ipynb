# %% [markdown]
# <a href="https://colab.research.google.com/github/niva1303-droid/Python---Data-Structures---Strings-Tuples/blob/main/Assignment_1_Strings_and_Tuples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. String Concatenation:**
#
#
# *   Write a Python program that takes two strings, i.e., string 1 "Hello" and string 2 “get name” as input from the user, and concatenates them together.
# *   Display the concatenated string as the output.
# *  Now, concatenate string 3, "Welcome to Python programming,” to the existing
# string and display the output string.

# %%
A = "Hello"
B = input("Enter the Name: ")
C = A + " " + B
print(C)
# Out:
# Enter the Name: Gayathri
# Hello Gayathri

# %%
D = "Welcome to Python Programming"
E = C + ", " + D
print(E)
# Out:
# Hello Gayathri, Welcome to Python Programming

# %% [markdown]
# **2. String Slicing and Indexing:**
# Write a Python program using the above concatenated string as input and perform
# the following tasks:
#
# a. Print the first character of the string.
#
# b. Print the last character of the string.
#
# c. Print the first 5 characters of the string.
#
# d. Print the last 11 characters of the string.
#
# e. Print the string in reverse.
#
# f. Use slicing and print the word “Python” from the existing string

# %%
print(E[0])
# Out:
# H

# %%
print(E[-1])
# Out:
# g

# %%
print(E[:5])
# Out:
# Hello

# %%
A = "Hello"
B = input("Enter the Name: ")
C = A + " " + B
print(C)
D = "Welcome to Python Programming"
E = C + ", " + D
print(E)
# Out:
# Enter the Name: Sowmiya
# Hello Sowmiya
# Hello Sowmiya, Welcome to Python Programming

# %%
print(E[-11:])
# Out:
# Programming

# %%
print(E[::-1])
# Out:
# gnimmargorP nohtyP ot emocleW ,ayimwoS olleH

# %%
print(E[26:32])
# Out:
# Python

# %% [markdown]
# **3. String Methods:**
# Write a Python program that takes a string, strM = “Python beginner tutorial," and performs the following tasks:
#
# a. Convert the sentence to uppercase.
#
# b. Convert the sentence to lowercase.
#
# c. Use Capitalize and return the sentence to the original input form.
#
# d. Count the total number of occurrences of character ‘t’ in the string.
#
# e. Replace all occurrences of “Python” with “Data Analytics” in the input string
# strM = “Python beginner tutorial.”

# %%
strM = "Python beginner tutorial"
print("Uppercase: ", strM.upper())
# Out:
# Uppercase:  PYTHON BEGINNER TUTORIAL

# %%
print("Lowercase: ", strM.lower())
# Out:
# Lowercase:  python beginner tutorial

# %%
print("Capitalize: ", strM.capitalize())
# Out:
# Capitalize:  Python beginner tutorial

# %%
print("Count of t: ", strM.count("t"))
# Out:
# Count of t:  3

# %%
print("Replace Python with Data Analytics: ", strM.replace("Python", "Data Analytics"))
# Out:
# Replace Python with Data Analytics:  Data Analytics beginner tutorial

# %% [markdown]
# **Tuples (Creation, Modification and Access) :**
#
# Create the 1st tuple with values -> (10, 20, 30) and the 2nd tuple with values -> (40, 50, 60):
#
# a. Concatenate the two tuples and store it in “t_combine”
#
# b. Repeat the elements of “t_combine” 3 times
#
# c. Access the 3rd element from “t_combine”
#
# d. Access the first three elements from “t_combine”
#
# e. Access the last three elements from “t_combine”

# %%
t1 = (10, 20, 30)
t2 = (40, 50, 60)
print(type(t1))
print(type(t2))
# Out:
# <class 'tuple'>
# <class 'tuple'>

# %%
t_combine = t1 + t2
print("T-Combine: ", t_combine)
# Out:
# T-Combine:  (10, 20, 30, 40, 50, 60)

# %%
print("Repeated Tuple: ", t_combine*3)
# Out:
# Repeated Tuple:  (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print("3rd Element: ", t_combine[2])
# Out:
# 3rd Element:  30

# %%
print("First 3 Elements: ", t_combine[:3])
# Out:
# First 3 Elements:  (10, 20, 30)

# %%
print("Last 3 Elements: ", t_combine[-3:])
# Out:
# Last 3 Elements:  (40, 50, 60)
